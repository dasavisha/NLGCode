# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#this notebook is for plotting the evaluation metrics for the pretrained models
#we plot the change in readability indexes for the models for varying (a)temperatures and (b)k sampling value 
PT_model_dict = {"openai-gpt": ["openai-gpt"], "gpt2": ["gpt2", "gpt2-medium", "gpt2-large"], "xlnet": ["xlnet-base-cased", "xlnet-large-cased"], "transfo-xl": ["transfo-xl-wt103"]}
models = ["human","fusion","openai-gpt", "gpt2", "gpt2-medium", "gpt2-large", "xlnet-base-cased", "xlnet-large-cased", "transfo-xl-wt103"]

# %% [markdown]
# # Plotting the Readability indexes

# %% [markdown]
# The values for varying temperature keeping the value of k constant

# %%
##Flesch Kincaid Grade
##list containing the flesch kincaid grade scores for all models at 
ori_fl_kincaid_grd = [7.714000]
gen_fl_kincaid_grd_t100 = [7.714000,8.504500,6.054000,9.284000,9.378000,8.371000,24.864130,11.264516,9.468000] #t=1.0 and k=0
gen_fl_kincaid_grd_t50 = [7.714000,7.34500,7.669065,7.134783,6.954074,7.387770,21.992187,12.863441,9.522388] #t=.5 and k=0
gen_fl_kincaid_grd_t75 = [7.714000,9.76540,6.324121,8.035000,9.394500,8.43250,39.791509,32.722222,10.234010] #t=.75 and k=0

# %%
#plot the FK Grade, x axis - temperature values and y axis - scores
temp_x = [0.5, 0.75, 1.00]
fk_grd_y = [gen_fl_kincaid_grd_t50, gen_fl_kincaid_grd_t75, gen_fl_kincaid_grd_t100 ]
plt.xlabel("Temperature")
plt.ylabel("F-K Grade Level")
plt.title("Flesch Kincaid Grade Level with varying temperature")
for i in range(len(fk_grd_y[0])):
    plt.plot(temp_x,[pt[i] for pt in fk_grd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/fk_grd_Tvar.pdf", format="pdf")
plt.show()

# %%
##Flesch Kincaid Reading Ease
##list containing the flesch kincaid reading ease for all models at 
ori_fl_rdng_ease = [65.731500]
gen_fl_rdng_ease_t100 = [65.731500,63.785000,76.743100,66.366600,65.822200,67.626900,-21.997391,62.989247,60.834200] #t=1.0 and k=0
gen_fl_rdng_ease_t50 = [65.731500,71.654300,56.972230,79.995725,78.779556,79.066547,-2.043594,46.821075,59.643209] #t=.5 and k=0
gen_fl_rdng_ease_t75 = [65.731500,59.765490,67.286533,67.158250,60.570450,69.17385,-129.994528,-106.012519,54.935279] #t=.75 and k=0

# %%
#plot the FK Reading ease, x axis - temperature values and y axis - scores
temp_x = [0.5, 0.75, 1.00]
fk_rd_y = [gen_fl_rdng_ease_t50, gen_fl_rdng_ease_t75, gen_fl_rdng_ease_t100 ]
plt.xlabel("Temperature")
plt.ylabel("F-K Reading Ease")
plt.title("Flesch Kincaid Reading Ease with varying temperature")
for i in range(len(fk_rd_y[0])):
    plt.plot(temp_x,[pt[i] for pt in fk_rd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/fk_rd_Tvar.pdf", format="pdf")
plt.show()

# %%
##Dale-Chall Readability Scores
##list containing the readability scores for all models at
#ori_dc_rd_score = [5.936900]
gen_dc_rd_score_t100 = [5.936900,7.34,6.200300,7.510500,7.509300,7.205900,3.770109,3.714516,8.049700] #t=1.0 and k=0
gen_dc_rd_score_t50 = [5.936900,3.678,2.297842,2.532391,2.733111,2.619496,3.574375,2.256344,5.264851] #t=.5 and k=0
gen_dc_rd_score_t75 = [5.936900,5.567,3.895930,5.260550,5.422500,5.71425,3.190472,2.932000,6.570508] #t=.75 and k=0

# %%
#plot the readability scores, x axis - temperature values and y axis - scores
temp_x = [0.5, 0.75, 1.00]
dc_rd_y = [gen_dc_rd_score_t50, gen_dc_rd_score_t75, gen_dc_rd_score_t100 ]
plt.xlabel("Temperature")
plt.ylabel("D-C Readability Scores")
plt.title("Dale-Chall Readability Scores with varying temperature")
for i in range(len(dc_rd_y[0])):
    plt.plot(temp_x,[pt[i] for pt in dc_rd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/dc_rd_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# The values for varying k keeping the temperature constant

# %%
##Flesch Kincaid Grade
##list containing the flesch kincaid grade scores for all models at 
ori_fl_kincaid_grd = [7.714000]
gen_fl_kincaid_grd_k0 = [7.714000,6.054000,6.054000,9.284000,9.378000,8.371000,24.864130,11.264516,9.468000] #t=1.0 and k=0
gen_fl_kincaid_grd_k5 = [7.714000,6.054000,6.598500,6.754211,7.962626,16.030808,19.424405,12.316867,9.006091] #t=1.0 and k=5
gen_fl_kincaid_grd_k10 = [7.714000,6.054000,5.773684,7.280469,6.078906,5.835115,26.238261,10.990083,8.439062] #t=1.0 and k=10
gen_fl_kincaid_grd_k150 = [7.714000,6.054000,5.181000,8.318000,7.868000,8.273500,23.060000,25.060510,10.184343] #t=1.0 and k=150
gen_fl_kincaid_grd_k1000 = [7.714000,6.054000,5.641500,8.254000,8.923000,8.906500,21.334646,24.874691,10.012500] #t=1.0 and k=1000
# print (len(gen_fl_kincaid_grd_k5))

# %%
#plot the FK Grade, x axis - K values and y axis - scores
topk_x = [0,5,10,150,1000]
fk_grd_y = [gen_fl_kincaid_grd_k0, gen_fl_kincaid_grd_k5, gen_fl_kincaid_grd_k10, gen_fl_kincaid_grd_k150, gen_fl_kincaid_grd_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("F-K Grade Level")
plt.title("Flesch Kincaid Grade Level with varying K")
plt.xscale('log')
# print (len(fk_grd_y[0]))
for i in range(len(fk_grd_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
#     print (i)
    plt.plot(topk_x,[pt[i] for pt in fk_grd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/fk_grd_Kvar.pdf", format="pdf")
plt.show()
# Out:
# 9

# %%
##Flesch Kincaid Reading Ease
##list containing the flesch kincaid reading ease for all models at 
ori_fl_rdng_ease = [65.731500]
gen_fl_rdng_ease_k0 = [65.731500,67.89,76.743100,66.366600,65.822200,67.626900,-21.997391,62.989247,60.834200] #t=1.0 and k=0
gen_fl_rdng_ease_k5 = [65.731500,75.90,73.210850,79.807526,74.735859,13.027273,17.366429,52.959699,61.275076] #t=1.0 and k=5
gen_fl_rdng_ease_k10 = [65.731500,81.18,78.019248,76.825625,80.201484,81.340229,-46.281304,52.717273,65.573828] #t=1.0 and k=10
gen_fl_rdng_ease_k150 = [65.731500,69.78,78.219650,70.492900,71.733450,71.898300,-20.715833,-48.980637,58.455707] #t=1.0 and k=150
gen_fl_rdng_ease_k1000 = [65.731500,63.23,76.971900,70.272400,65.089150,67.579150,0.526614,-47.057716,59.554800] #t=1.0 and k=1000
print (len(gen_fl_rdng_ease_k1000))
# Out:
# 9

# %%
#plot the FK Reading ease, x axis - K values and y axis - scores
topk_x = [0,5,10,150,1000]
fk_rd_y = [gen_fl_rdng_ease_k0, gen_fl_rdng_ease_k5, gen_fl_rdng_ease_k10, gen_fl_rdng_ease_k150, gen_fl_rdng_ease_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("F-K Reading Ease")
plt.title("Flesch Kincaid Reading Ease with varying K")
plt.xscale('log')
for i in range(len(fk_rd_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in fk_rd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/fk_rd_Kvar.pdf", format="pdf")
plt.show()

# %%
##Dale-Chall Readability Scores
##list containing the readability scores for all models at
ori_dc_rd_score = [5.936900]
gen_dc_rd_score_k0 = [5.936900,7.231,6.200300,7.510500,7.509300,7.205900,3.770109,3.714516,8.049700] #t=1.0 and k=0
gen_dc_rd_score_k5 = [5.936900,3.672,3.779900,3.036105,3.741768,3.682121,3.026369,2.737229,5.814416] #t=1.0 and k=5
gen_dc_rd_score_k10 = [5.936900,4.231,4.246241,3.915391,4.706406,4.373511,2.506261,2.894628,6.520156] #t=1.0 and k=10
gen_dc_rd_score_k150 = [5.936900,5.467,5.425450,6.663500,6.529400,6.824900,3.913583,3.688599,7.400707] #t=1.0 and k=150
gen_dc_rd_score_k1000 = [5.936900,6.341,5.932550,7.159950,7.173100,7.061200,4.557717,3.767346,7.774450] #t=1.0 and k=1000

# %%
#plot the Dale Chall Readability, x axis - K values and y axis - scores
topk_x = [0,5,10,150,1000]
dc_rd_y = [gen_dc_rd_score_k0, gen_dc_rd_score_k5, gen_dc_rd_score_k10, gen_dc_rd_score_k150, gen_dc_rd_score_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("D-C Readability Sores")
plt.title("Dale-Chall Readability Scores with varying K")
plt.xscale('log')
for i in range(len(dc_rd_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in dc_rd_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/dc_rd_Kvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# # Plotting the Average Sentence Length

# %% [markdown]
# The average sentence length with varying temperature

# %%
##list the average sentence length for varying temperature
gen_avg_SL_t100 = [11.363143139452303,12.5679,13.305764926704494,18.90429102487926,15.534194774094155,16.387633874287754,28.93798818364679,21.596846928439668,18.9236143123398] #t=1.0 and k=0
gen_avg_SL_t50 = [11.363143139452303,19.452,9.534249298080061,17.82861838582505,21.072886086296705,20.32177605176335,26.163671841744673,19.273062893202603,15.697886184074488] #t=.5 and k=0
gen_avg_SL_t75 = [11.363143139452303,15.7431,10.060078207568147,15.61238262991866,15.532898977768959,17.611282170293588,24.511647737660684,18.438420512611167,17.120848725835568] #t=.75 and k=0

# %%
#plot the average sentence length
temp_x = [0.5, 0.75, 1.00]
avg_SL_y = [gen_avg_SL_t50, gen_avg_SL_t75, gen_avg_SL_t100 ]
plt.xlabel("Temperature")
plt.ylabel("Average Sentence Length")
plt.title("Average Sentence Length with varying temperature")
for i in range(len(avg_SL_y[0])):
    plt.plot(temp_x,[pt[i] for pt in avg_SL_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/avg_SL_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# The average sentence length with varying k

# %%
#plot the average sentence length
gen_avg_SL_k0 = [11.829186376171327,12.87536,13.305764926704494,18.90429102487926,15.534194774094155,16.387633874287754,28.93798818364679,21.596846928439668,18.9236143123398] #t=1.0 and k=0
gen_avg_SL_k5 = [11.829186376171327,15.09561,14.26237587872224,18.524836176071663,17.668263468134903,16.335946605853728,31.23044975499103,24.29682707498505,15.14001301932072] #t=1.0 and k=5
gen_avg_SL_k10 = [11.829186376171327,16.13489,13.703488655384776,18.868075232231774,15.313186457410602,14.126501029626665,29.231645138450443,18.963334251430435,16.228687807918575] #t=1.0 and k=10
gen_avg_SL_k150 = [11.829186376171327,16.45763,10.804261898522912,17.970917552973535,16.92798318674789,19.15581587162837,24.26925550170074,17.103978926887006,19.43540366227149] #t=1.0 and k=150
gen_avg_SL_k1000 = [11.829186376171327,17.0956,11.667284281959011,17.033273171273173,16.135401224263298,18.916080891330893,23.99311779373623,19.536958141735322,19.077293456543458] #t=1.0 and k=1000

# %%
#plot the average sent length, x axis - K values and y axis - scores
topk_x = [0,5,10,150,1000]
avg_SL_y = [gen_avg_SL_k0, gen_avg_SL_k5, gen_avg_SL_k10, gen_avg_SL_k150, gen_avg_SL_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("Average Sentence Length")
plt.title("Average Sentence Length with varying K")
plt.xscale('log')
for i in range(len(avg_SL_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in avg_SL_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/avg_SL_Kvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# # Plotting the percentage of N gram overlap

# %% [markdown]
# Unigrams with varying temperature keeping the K constant

# %%
gen_ug_ovlp_t100 = [16.170480542094214,15.7845,20.610826572127166,18.42605237830635,18.26894940675688,21.03866089219136,43.58028174363607,45.73300889152763,19.483739708291427]
gen_ug_ovlp_t50 = [15.856470069707008,16.532,26.280900477690633,41.59748115862388,38.96703850288115,40.740263174993046,48.957595588718675,53.99353743244974,24.29388972297799]
gen_ug_ovlp_t75 = [16.17799718374199,19.78067,22.48880973946581,32.20972501088443,30.738677774754077,31.104218280691406,46.37769321772924,52.12542314900854,24.323972489175432]

# %%
temp_x = [0.5, 0.75, 1.00]
ug_ovlp_y = [gen_ug_ovlp_t50, gen_ug_ovlp_t75, gen_ug_ovlp_t100]
plt.xlabel("Temperature")
plt.ylabel("% of 1-gram overlap with prompt")
plt.title("Unigram overlap percentage with prompt with varying temperature")
for i in range(len(ug_ovlp_y[0])):
    plt.plot(temp_x,[pt[i] for pt in ug_ovlp_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/ug_ovlp_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# Bigrams with varying temperature keeping the K constant

# %%
gen_bg_ovlp_t100 = [0.8269622331653846,0.7867,0.9736895069661108,1.4130960164066124,1.3349620119164671,2.2980755815601017,19.114493304879552,20.64556306325278,0.9644955559033629]
gen_bg_ovlp_t50 = [0.6765485089086241,1.90267,4.304218039521535,15.584648422610531,12.115635331978437,14.941869645546147,21.50118019748704,28.441450470952343,2.736741653302924]
gen_bg_ovlp_t75 = [0.751313415709465,3.5642,1.7642539230020504,9.367583835734258,6.474191132687463,8.512986929492811,15.70022878790645,23.020121291510552,1.6534005451323965]

# %%
temp_x = [0.5, 0.75, 1.00]
bg_ovlp_y = [gen_bg_ovlp_t50, gen_bg_ovlp_t75, gen_bg_ovlp_t100]
plt.xlabel("Temperature")
plt.ylabel("% of 2-gram overlap with prompt")
plt.title("Bigram overlap percentage with prompt with varying temperature")
for i in range(len(bg_ovlp_y[0])):
    plt.plot(temp_x,[pt[i] for pt in bg_ovlp_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/bg_ovlp_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# Trigrams with varying temperature keeping the K constant

# %%
gen_tg_ovlp_t100 = [0.20499172887662268,0,0.13541892322970758,0.544961765878673,0.3632414224650863,1.0961403764420252,15.923380462759953,17.405862209792616,0.15662947303506095]
gen_tg_ovlp_t50 = [0.14910350700701125,0,1.6115417590015542,10.208061511967214,8.654216741511521,9.281106417700515,24.791649133211905,29.588220428340513,0.9199270965069019]
gen_tg_ovlp_t75 = [0.1684901008728041,0,0.4306073246168141,6.1437039864825325,3.397419276578996,4.9734295797873225,18.42675996153472,21.359422263504236,0.2608585358903579]

# %%
temp_x = [0.5, 0.75, 1.00]
tg_ovlp_y = [gen_tg_ovlp_t50, gen_tg_ovlp_t75, gen_tg_ovlp_t100]
plt.xlabel("Temperature")
plt.ylabel("% of 3-gram overlap with prompt")
plt.title("Trigram overlap percentage with prompt with varying temperature")
for i in range(len(tg_ovlp_y[0])):
    plt.plot(temp_x,[pt[i] for pt in tg_ovlp_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/tg_ovlp_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# Unigrams with varying k values keeping the temperature constant

# %%
gen_ug_ovlp_k0 = [16.170480542094214,21.789,20.610826572127166,18.42605237830635,18.26894940675688,21.03866089219136,43.58028174363607,45.73300889152763,19.483739708291427]
gen_ug_ovlp_k5 = [16.058587587094987,34.9081,27.192152453959956,44.406181130622464,41.48246397576907,40.475624381985114,60.618225780781565,59.636561522985915,26.9552511897951]
gen_ug_ovlp_k10 = [17.051826116662824,31.4562,26.967012221478967,38.277795770126794,32.6723965644199,35.300273150975144,60.61958847658129,60.92521739558833,23.4298848672324]
gen_ug_ovlp_k150 = [17.12126475402636,20.9867,21.629926354549134,21.863324794136737,22.94978966730388,20.907496988666498,43.64629219451909,43.67774398228449,22.403250716788154]
gen_ug_ovlp_k1000 = [16.445282921386383,19.3452,20.078311878853583,20.082925619930304,19.55482273440397,20.467319638822314,45.26510994857818,38.92588434120631,20.316678407778188]

# %%
topk_x = [0,5,10,150,1000]
ug_ovlp_y = [gen_ug_ovlp_k0, gen_ug_ovlp_k5, gen_ug_ovlp_k10, gen_ug_ovlp_k150, gen_ug_ovlp_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of 1-gram overlap with prompt")
plt.title("Unigram overlap percentage with prompt with varying K")
plt.xscale('log')
for i in range(len(ug_ovlp_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in ug_ovlp_y],label = models[i],marker='o')

plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/ug_ovlp_Kvar.pdf", format="pdf")
plt.show()

# %%
gen_bg_ovlp_k0 = [0.8269622331653846,0.8675425,0.9736895069661108,1.4130960164066124,1.3349620119164671,2.2980755815601017,19.114493304879552,20.64556306325278,0.9644955559033629]
gen_bg_ovlp_k5 = [0.8428305175693369,0.786256,3.6669205557617834,18.458574467469955,17.123259864748537,14.286534666096166,35.49764150927873,35.05548933578043,3.9244768587417256]
gen_bg_ovlp_k10 = [0.9131634019769244,1.563587,3.46197162890656,10.098105433423877,7.763290337681168,10.725498085110928,37.94257149103282,38.434334162373844,2.769873451867]
gen_bg_ovlp_k150 = [0.9469060767037505,0.936738,1.2651123349128919,2.579592781332391,2.912407868426592,1.6150176502664613,15.07901324277589,15.536766089758668,1.3195312776973303]
gen_bg_ovlp_k1000 = [1.0830119162890026,0.756443,0.8726149452201626,1.6598340157066034,1.3859114024340367,1.3652617790905963,14.925196053783814,14.094031950300165,1.0327536606806427]

# %%
topk_x = [0,5,10,150,1000]
bg_ovlp_y = [gen_bg_ovlp_k0, gen_bg_ovlp_k5, gen_bg_ovlp_k10, gen_bg_ovlp_k150, gen_bg_ovlp_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of 2-gram overlap with prompt")
plt.title("Bigram overlap percentage with prompt with varying K")
plt.xscale('log')
for i in range(len(bg_ovlp_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in bg_ovlp_y],label = models[i],marker='o')

plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/bg_ovlp_Kvar.pdf", format="pdf")
plt.show()

# %%
gen_tg_ovlp_k0 = [0.20499172887662268,0.13541892322970758,0.544961765878673,0.3632414224650863,1.0961403764420252,15.923380462759953,17.405862209792616,0.15662947303506095]
gen_tg_ovlp_k5 = [0.22300362534281087,1.246402131063921,11.855784206965987,11.108581316555497,8.246839110029047,29.134732658156,31.068906643925803,1.3299825957633613]
gen_tg_ovlp_k10 = [0.2623902773212847,1.3637832184172443,6.2895173604512955,4.833283880492531,6.487100182507191,32.8905126958784,32.47785976042863,0.45860664855285727]
gen_tg_ovlp_k150 = [0.21962425368662034,0.14701871654267668,1.3305691754352735,1.3519713322655222,0.37939591154023716,15.679714172960065,13.338091069355182,0.13927114211626143]
gen_tg_ovlp_k1000 = [0.38908939416779637,0.09598333111486444,0.7090476101023827,0.22889786139990373,0.37614945662462396,16.58697253949514,11.091739066065003,0.18030938065668453]

# %%
topk_x = [0,5,10,150,1000]
tg_ovlp_y = [gen_tg_ovlp_k0, gen_tg_ovlp_k5, gen_tg_ovlp_k10, gen_tg_ovlp_k150, gen_tg_ovlp_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of 3-gram overlap with prompt")
plt.title("Trigram overlap percentage with prompt with varying K")
plt.xscale('log')
for i in range(len(tg_ovlp_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in tg_ovlp_y],label = models[i],marker='o')

plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/tg_ovlp_Kvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# # Percentage of Content Words V/S Stopword

# %% [markdown]
# The percentage of content words by varying the temperature keeping K constant

# %%
gen_avg_cw_t100 = [0.6327421711376032,0.5642248349717914,0.6034169999976341,0.617477354484942,0.5808474021008991,0.7007965789375928,0.6499379801326453,0.6228205192516448]
gen_avg_cw_t50 = [0.6274646942222298,0.6209385571776062,0.5472086315998671,0.5428868082953054,0.516179997489602,0.8241746555541475,0.7220968086127865,0.6165704489421431]
gen_avg_cw_t75 = [0.6343718071629472,0.6042096135052446,0.5625065939904872,0.5578652065438118,0.5753681845201093,0.8078208018182844,0.7536058787792324,0.6078784382341657]

# %%
#plot the 
temp_x = [0.5, 0.75, 1.00]
avg_cw_y = [gen_avg_cw_t50, gen_avg_cw_t75, gen_avg_cw_t100 ]
plt.xlabel("Temperature")
plt.ylabel("% of Content Words")
plt.title("Percentage of content words with varying temperature")
for i in range(len(avg_cw_y[0])):
    plt.plot(temp_x,[pt[i]*100 for pt in avg_cw_y],label = models[i],marker='o')
plt.legend(loc=0, prop={'size':8})
plt.savefig("../results/plots/avg_cw_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# The percentage of content words by varying the K keeping temperature constant

# %%
gen_avg_cw_k0 = [0.6327421711376032,0.5642248349717914,0.6034169999976341,0.617477354484942,0.5808474021008991,0.7007965789375928,0.6499379801326453,0.6228205192516448]
gen_avg_cw_k5 = [0.6289559926784539,0.5471416792046854,0.5425814299260174,0.5475656700426663,0.5486183609328692,0.6720491673083157,0.654336518956028,0.5848347683358076]
gen_avg_cw_k10 = [0.633393605364598,0.5396513691629763,0.5366505132607349,0.5479277591564684,0.54691542948083,0.6553716883604521,0.6133701209140259,0.587719915942893]
gen_avg_cw_k150 = [0.6260635329710901,0.5609060917412853,0.5599164400951029,0.5766358830024907,0.5885888132728431,0.7855361497394318,0.7074405535721995,0.6067296317490075]
gen_avg_cw_k1000 = [0.6269783512890413,0.5683344651727366,0.5735635195784793,0.5923018600195169,0.5923018600195169,0.7800563993753329,0.693662096665342,0.6099787955708984]

# %%
topk_x = [0,5,10,150,1000]
avg_cw_y = [gen_avg_cw_k0, gen_avg_cw_k5, gen_avg_cw_k10, gen_avg_cw_k150, gen_avg_cw_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of Content Words")
plt.title("Percentage of content words with varying K")
plt.xscale('log')
for i in range(len(avg_cw_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i]*100 for pt in avg_cw_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/avg_cw_Kvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# # Part of Speech Usage probability

# %% [markdown]
# Frequency distribution of POS tags varying with temperature

# %%
##frequency distribution of the noun and verb tags
#NOUN: 14.975097181470302 and VERB: 18.054275563589087 -- original
gen_noun_t100 = [14.975097181470302,18.7890234,14.752797277588106,17.6871766472424,17.081444173720875,15.956242459171092,18.296942208720573,16.192835625870377,17.835422054385823]
gen_noun_t50 = [14.975097181470302,17.954390,10.617586276684873,19.421236118544222,18.160841091622785,17.99426338854831,20.173638075638152,20.72429129823286,17.2052204846887]
gen_noun_t75 = [14.975097181470302,17.6705489,9.701299826888357,16.705519780004156,16.32516959694015,18.212389331083106,16.704149618209808,18.184504620988022,17.44369054001325]

# %%
temp_x = [0.5, 0.75, 1.00]
noun_y = [gen_noun_t50, gen_noun_t75, gen_noun_t100]
plt.xlabel("Temperature")
plt.ylabel("% of Noun usage")
plt.title("Percentage of Nouns with varying temperature")
for i in range(len(noun_y[0])):
    plt.plot(temp_x,[pt[i] for pt in noun_y],label = models[i],marker='o')
plt.legend(loc=0, prop={'size':8})
plt.savefig("../results/plots/noun_Tvar.pdf", format="pdf")
plt.show()

# %%
gen_verb_t100 = [18.054275563589087,18.01348766,19.431401731916097,17.06511574777808,17.9418602431312,18.075299876054277,14.724597988633,18.33432015495131,14.27146923350548]
gen_verb_t50 = [18.054275563589087,18.6775431,19.141848567486672,19.722453887156433,20.869677016579992,20.276991182873367,17.103051909884904,19.38349965198206,13.599870519094392]
gen_verb_t75 = [18.054275563589087,19.87561567,20.263437178009973,17.506498845874734,19.658702247098017,17.954918387564256,16.926579484317873,18.506752983407356,14.339599840653333]

# %%
temp_x = [0.5, 0.75, 1.00]
verb_y = [gen_verb_t50, gen_verb_t75, gen_verb_t100]
plt.xlabel("Temperature")
plt.ylabel("% of Verb usage")
plt.title("Percentage of Verbs with varying temperature")
for i in range(len(verb_y[0])):
    plt.plot(temp_x,[pt[i] for pt in verb_y],label = models[i],marker='o')
plt.legend(loc=0, prop={'size':8})
plt.savefig("../results/plots/verb_Tvar.pdf", format="pdf")
plt.show()

# %% [markdown]
# POS tags with varying K values keeping the temperature constant

# %%
gen_noun_k0 = [14.975097181470302,18.01346,14.752797277588106,17.6871766472424,17.081444173720875,15.956242459171092,18.296942208720573,16.192835625870377,17.835422054385823]
gen_noun_k5 = [14.975097181470302,17.245739,12.642395792396838,16.972289003386987,16.911691375086672,17.06729695791785,18.68259528994638,18.04291981899038,18.19580108609387]
gen_noun_k10 = [14.975097181470302,15.89027,12.123045479832673,15.821762519740473,15.614743198491302,15.3935493589989,19.859223342917417,18.66751307858286,18.055094613066338]
gen_noun_k150 = [14.975097181470302,15.78029,12.628754164891069,16.40679480651106,16.409908413946354,16.387883212700032,17.056955403792923,17.680204336109952,17.874106877666172]
gen_noun_k1000 = [14.975097181470302,17.107827830,13.643422573195913,17.00819357297595,17.214759477790256,16.530403862120547,19.290521827682767,16.726844952368943,17.953590244282427]

# %%
topk_x = [0,5,10,150,1000]
noun_y = [gen_noun_k0, gen_noun_k5, gen_noun_k10, gen_noun_k150, gen_noun_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of Noun usage")
plt.title("Percentage of Nouns with varying K")
plt.xscale('log')
for i in range(len(noun_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in noun_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/noun_Kvar.pdf", format="pdf")
plt.show()

# %%
gen_verb_k0 = [18.054275563589087,18.06752680,19.431401731916097,17.06511574777808,17.9418602431312,18.075299876054277,14.724597988633,18.33432015495131,14.27146923350548]
gen_verb_k5 = [18.054275563589087,20.8928602,21.276676620173728,21.661835769250526,21.636321839413437,19.49441025953575,18.599730315638542,19.95040843749227,15.637615770472927]
gen_verb_k10 = [18.054275563589087,21.004572692,21.711346248838108,20.88949584636508,20.8694494901091,20.01966029406106,17.28449537936263,19.783174854475078,15.238152278986696]
gen_verb_k150 = [18.054275563589087,19.579873,20.34714582142553,18.213098822867394,18.249963277768654,16.339235181487243,14.608791561057124,15.96932500276616,14.299362746989914]
gen_verb_k1000 = [18.054275563589087,18.6483693,19.24898085500481,17.495638805890415,17.53333860569092,16.274778773366695,13.891099449607067,15.946683603036762,14.416439146791829]

# %%
topk_x = [0,5,10,150,1000]
verb_y = [gen_verb_k0, gen_verb_k5, gen_verb_k10, gen_verb_k150, gen_verb_k1000]
plt.xlabel("k (Top-k sampling)")
plt.ylabel("% of Verb usage")
plt.title("Percentage of Verbs with varying K")
plt.xscale('log')
for i in range(len(verb_y[0])):
#     plt.loglog(topk_x, [pt[i] for pt in fk_grd_y],label = models[i],marker='o')
    plt.plot(topk_x,[pt[i] for pt in verb_y],label = models[i],marker='o')
plt.legend(loc=5, prop={'size':8})
plt.savefig("../results/plots/verb_Kvar.pdf", format="pdf")
plt.show()
